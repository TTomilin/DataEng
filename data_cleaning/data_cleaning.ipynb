# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./opsd-time_series-2019-06-05/time_series_60min_singleindex.csv")

# %%
df.head()
# Out:
#           utc_timestamp        cet_cest_timestamp  \
# 0  2004-12-31T23:00:00Z  2005-01-01T00:00:00+0100
# 1  2005-01-01T00:00:00Z  2005-01-01T01:00:00+0100
# 2  2005-01-01T01:00:00Z  2005-01-01T02:00:00+0100
# 3  2005-01-01T02:00:00Z  2005-01-01T03:00:00+0100
# 4  2005-01-01T03:00:00Z  2005-01-01T04:00:00+0100
#
#    AL_load_actual_entsoe_power_statistics  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    AT_load_actual_entsoe_power_statistics  AT_load_actual_entsoe_transparency  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# ...

# %%
# Get subset of the first 5000 rows
df_subset = df.drop(df.index[:-5000])

# %%
# drop all NaN for now
df_subset.dropna(axis='columns', how='all', inplace=True)  # thresh=4000)

# %%
# Write back to .csv
df_subset.to_csv('reduced_dataset.csv')
